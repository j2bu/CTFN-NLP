# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# #### Note: The main Python packages that enable us to easily acquire financial data include yFinance, Alpha Vintage, and Pandas-DataReader. Among them, yFinance is the most widely used one. Here we pick yfinance to acquire the stock data.

# %%
df = pd.read_csv('/ctfn.csv')

# %%
df
# Out:
#      M&T Has "No Choice" But to See Hudson City Deal to Conclusion, Expert Says  \
# 0     Why Rumors of a PACCAR Acquisition by Volkswag...
# 1     Did Valeant and Pershing Square Side Step Insi...
# 2     Valeant Responds to Allergan's Insider Trading...
# 3     Is the O'Hagan Precedent Central to Ackman's D...
# 4     The Judge Who Will Preside Over Allergan's Ins...
# ...                                                 ...
# 2741  CMA Plans For MGM/Amazon Not Apparent as EC Wr...
# 2742  While KKR Bid Looms, Telecom Italia Sees More ...
# 2743  CTFN Analysis: What Can Observers Expect from ...
# 2744  FTC Commissioner Nominee Once Again Slowed in ...
# 2745  Flurry of TomTom-Microsoft Engagement Fuels St...
#
#       2014-01-27 10:07:22     HCBK  MTB Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     2014-07-31 11:32:52     PCAR  NaN        NaN        NaN        NaN
# 1     2014-08-15 11:32:10      AGN  VRX        NaN        NaN        NaN
# 2     2014-08-18 11:30:52      AGN  VRX        NaN        NaN        NaN
# 3     2014-08-18 11:31:35      AGN  VRX        NaN        NaN        NaN
# 4     2014-08-19 11:30:31      AGN  VRX        NaN        NaN        NaN
# ...                   ...      ...  ...        ...        ...        ...
# 2741  2022-03-16 14:58:09     AMZN  NaN        NaN        NaN        NaN
# 2742  2022-03-17 10:28:02   TIT:IM  NaN        NaN        NaN        NaN
# 2743  2022-03-17 12:16:55     PGRE  NaN        NaN        NaN        NaN
# 2744  2022-03-18 10:41:49      NaN  NaN        NaN        NaN        NaN
# 2745  2022-03-18 11:19:39  TOM2:NA  NaN        NaN        NaN        NaN
#
#      Unnamed: 7
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2741        NaN
# 2742        NaN
# 2743        NaN
# 2744        NaN
# 2745        NaN
#
# [2746 rows x 8 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
df.loc[-1] = [df.columns[0], df.columns[1], df.columns[2],df.columns[3], np.NaN, np.NaN, np.NaN, np.NaN]  # adding a row
df.index = df.index + 1
df = df.sort_index()
df
# Out:
#      M&T Has "No Choice" But to See Hudson City Deal to Conclusion, Expert Says  \
# 0     M&T Has "No Choice" But to See Hudson City Dea...
# 1     Why Rumors of a PACCAR Acquisition by Volkswag...
# 2     Did Valeant and Pershing Square Side Step Insi...
# 3     Valeant Responds to Allergan's Insider Trading...
# 4     Is the O'Hagan Precedent Central to Ackman's D...
# ...                                                 ...
# 2742  CMA Plans For MGM/Amazon Not Apparent as EC Wr...
# 2743  While KKR Bid Looms, Telecom Italia Sees More ...
# 2744  CTFN Analysis: What Can Observers Expect from ...
# 2745  FTC Commissioner Nominee Once Again Slowed in ...
# 2746  Flurry of TomTom-Microsoft Engagement Fuels St...
#
#       2014-01-27 10:07:22     HCBK  MTB Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     2014-01-27 10:07:22     HCBK  MTB        NaN        NaN        NaN
# 1     2014-07-31 11:32:52     PCAR  NaN        NaN        NaN        NaN
# 2     2014-08-15 11:32:10      AGN  VRX        NaN        NaN        NaN
# 3     2014-08-18 11:30:52      AGN  VRX        NaN        NaN        NaN
# 4     2014-08-18 11:31:35      AGN  VRX        NaN        NaN        NaN
# ...                   ...      ...  ...        ...        ...        ...
# 2742  2022-03-16 14:58:09     AMZN  NaN        NaN        NaN        NaN
# 2743  2022-03-17 10:28:02   TIT:IM  NaN        NaN        NaN        NaN
# 2744  2022-03-17 12:16:55     PGRE  NaN        NaN        NaN        NaN
# 2745  2022-03-18 10:41:49      NaN  NaN        NaN        NaN        NaN
# 2746  2022-03-18 11:19:39  TOM2:NA  NaN        NaN        NaN        NaN
#
#      Unnamed: 7
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2742        NaN
# 2743        NaN
# 2744        NaN
# 2745        NaN
# 2746        NaN
#
# [2747 rows x 8 columns]

# %%
#change column names
df.columns = ['Headline','Date','Stock1','Stock2','Stock3','Stock4','Stock5','Stock6']
df
# Out:
#                                                Headline                 Date  \
# 0     M&T Has "No Choice" But to See Hudson City Dea...  2014-01-27 10:07:22
# 1     Why Rumors of a PACCAR Acquisition by Volkswag...  2014-07-31 11:32:52
# 2     Did Valeant and Pershing Square Side Step Insi...  2014-08-15 11:32:10
# 3     Valeant Responds to Allergan's Insider Trading...  2014-08-18 11:30:52
# 4     Is the O'Hagan Precedent Central to Ackman's D...  2014-08-18 11:31:35
# ...                                                 ...                  ...
# 2742  CMA Plans For MGM/Amazon Not Apparent as EC Wr...  2022-03-16 14:58:09
# 2743  While KKR Bid Looms, Telecom Italia Sees More ...  2022-03-17 10:28:02
# 2744  CTFN Analysis: What Can Observers Expect from ...  2022-03-17 12:16:55
# 2745  FTC Commissioner Nominee Once Again Slowed in ...  2022-03-18 10:41:49
# 2746  Flurry of TomTom-Microsoft Engagement Fuels St...  2022-03-18 11:19:39
#
#        Stock1 Stock2 Stock3 Stock4 Stock5 Stock6
# 0        HCBK    MTB    NaN    NaN    NaN    NaN
# 1        PCAR    NaN    NaN    NaN    NaN    NaN
# 2         AGN    VRX    NaN    NaN    NaN    NaN
# 3         AGN    VRX    NaN    NaN    NaN    NaN
# 4         AGN    VRX    NaN    NaN    NaN    NaN
# ...       ...    ...    ...    ...    ...    ...
# 2742     AMZN    NaN    NaN    NaN    NaN    NaN
# 2743   TIT:IM    NaN    NaN    NaN    NaN    NaN
# 2744     PGRE    NaN    NaN    NaN    NaN    NaN
# 2745      NaN    NaN    NaN    NaN    NaN    NaN
# 2746  TOM2:NA    NaN    NaN    NaN    NaN    NaN
#
# [2747 rows x 8 columns]

# %%
headline = []
open_pr = []
close_pr = []

# %%
len(df)
# Out:
# 2747

# %% [markdown]
# #### We can only extract 500 stocks each time using yf.Ticker, and therefore we need approximately 6 times in total to extract all stocks. It takes a considerable amount of time to run each time, so we only run the test with the first 500 stocks to show how it's done.

# %%
#for i in range(len(df)):
for i in range(0,500):
    #Stock1
    if pd.isna(df.iloc[i]['Stock1']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock1']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
    #Stock2
    if pd.isna(df.iloc[i]['Stock2']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock2']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
    #Stock3
    if pd.isna(df.iloc[i]['Stock3']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock3']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
    #Stock4
    if pd.isna(df.iloc[i]['Stock4']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock4']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
    #Stock5
    if pd.isna(df.iloc[i]['Stock5']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock5']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
    #Stock6
    if pd.isna(df.iloc[i]['Stock6']) == False:
        date = df.iloc[i]['Date'][0:10]
        yfd = yf.Ticker(df.iloc[i]['Stock6']).history(start = date)
        if len(yfd) !=0:
            headline.append(df.iloc[i]['Headline'])
            open_pr.append(yfd.iloc[0]['Open'])
            close_pr.append(yfd.iloc[0]['Close'])
# Out:
# - HCBK: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - GNC: No data found, symbol may be delisted
# - VSI: No data found, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - LTM: No data found, symbol may be delisted
# - WIN: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - NQ: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - ANN: No data found for this date range, symbol may be delisted
# - DWA: No data found for this date range, symbol may be delisted
# - RAX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - FEYE: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - ARCP: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - BBRY: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - GMCR: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - SNE: No data found, symbol may be delisted
# - SNC: No data found for this date range, symbol may be delisted
# - DWA: No data found for this date range, symbol may be delisted
# - GMCR: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - AV: No data found for this date range, symbol may be delisted
# - PHNX: No data found, symbol may be delisted
# - ARCP: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - KORS: No data found for this date range, symbol may be delisted
# - WFM: No data found for this date range, symbol may be delisted
# - AOL: No data found for this date range, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - CBST: No data found for this date range, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FDO: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - RAX: No data found for this date range, symbol may be delisted
# - FMMC: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - HSP: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - NBG: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - OWW: No data found for this date range, symbol may be delisted
# - PCLN: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - WMGI: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - ANN: No data found for this date range, symbol may be delisted
# - DISCA: No data found, symbol may be delisted
# - SLXP: No data found for this date range, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - FSL: No data found for this date range, symbol may be delisted
# - FSL: No data found for this date range, symbol may be delisted
# - ADVS: No data found for this date range, symbol may be delisted
# - LO: No data found for this date range, symbol may be delisted
# - RAI: No data found for this date range, symbol may be delisted
# - KRFT: No data found for this date range, symbol may be delisted
# - OWW: No data found for this date range, symbol may be delisted
# - PCLN: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTRX: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTRX: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - HRS: No data found, symbol may be delisted
# - XLS: No data found for this date range, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - ASPX: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - OWW: No data found for this date range, symbol may be delisted
# - PCLN: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - LO: No data found for this date range, symbol may be delisted
# - RAI: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - OCR: No data found for this date range, symbol may be delisted
# - TIF: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - DWA: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - WMGI: No data found, symbol may be delisted
# - WIN: No data found, symbol may be delisted
# - CSAL: No data found for this date range, symbol may be delisted
# - LO: No data found for this date range, symbol may be delisted
# - RAI: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - TYVIX: No data found, symbol may be delisted
# - CACQ: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - CTRX: No data found for this date range, symbol may be delisted
# - DPLO: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - LVLT: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - DTV: No data found, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - APC: No data found, symbol may be delisted
# - COG: No data found, symbol may be delisted
# - WLH: No data found, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - WBAI: No data found, symbol may be delisted
# - HNT: No data found for this date range, symbol may be delisted
# - AGII: No data found for this date range, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - DEPO: No data found for this date range, symbol may be delisted
# - FNSR: No data found, symbol may be delisted
# - JDSU: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - RDS-A: No data found, symbol may be delisted
# - BRGYY: No data found for this date range, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - CNW: No data found for this date range, symbol may be delisted
# - OSH.AX: No data found, symbol may be delisted
# - OSH.AX: No data found, symbol may be delisted
# - IOC: No data found for this date range, symbol may be delisted
# - RDS-B: No data found, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - RDS-A: No data found, symbol may be delisted
# - BRGYY: No data found for this date range, symbol may be delisted
# - ETH: No data found, symbol may be delisted
# - OSH.AX: No data found, symbol may be delisted
# - TOT: No data found, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - POT: No data found for this date range, symbol may be delisted
# - RSA.L: No data found, symbol may be delisted
# - ZURN.VX: No data found, symbol may be delisted
# - WMGI: No data found, symbol may be delisted
# - KCR1V.HE: No data found, symbol may be delisted
# - LVLT: No data found for this date range, symbol may be delisted
# - ZAYO: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - WFT: No data found, symbol may be delisted
# - FI: No data found, symbol may be delisted
# - SYR.L: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATML: No data found for this date range, symbol may be delisted
# - DLG.DE: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - COS.TO: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - KCR1V.HE: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - REMY: No data found for this date range, symbol may be delisted
# - WIN.DE: No data found, symbol may be delisted
# - SNDK: No data found for this date range, symbol may be delisted
# - COS.TO: No data found for this date range, symbol may be delisted
# - WIN.DE: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - ATML: No data found for this date range, symbol may be delisted
# - DLG.DE: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - WFM: No data found for this date range, symbol may be delisted
# - TFM: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - ATML: No data found for this date range, symbol may be delisted
# - DLG.DE: No data found, symbol may be delisted
# - ATML: No data found for this date range, symbol may be delisted
# - DLG.DE: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTL: No data found, symbol may be delisted
# - CTL: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTL: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - COS.TO: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - VRX: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SNDK: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - BG.L: No data found for this date range, symbol may be delisted
# - RDS-A: No data found, symbol may be delisted
# - RDSB.L: No data found, symbol may be delisted
# - ZAYO: No data found, symbol may be delisted
# - TCY.L: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - FEYE: No data found, symbol may be delisted
# - QLIK: No data found for this date range, symbol may be delisted
# - DATA: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - POT: No data found for this date range, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - ATML: No data found for this date range, symbol may be delisted
# - DLG.DE: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - FCS: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - BXLT: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - OIBR: No data found for this date range, symbol may be delisted
# - TI: No data found, symbol may be delisted
# - CBS: No data found, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - CIT: No data found, symbol may be delisted
# - CTL: No data found, symbol may be delisted
# - DISCA: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - KIRI: No data found, symbol may be delisted
# - 2502: No data found, symbol may be delisted
# - GMCR: No data found for this date range, symbol may be delisted
# - BXLT: No data found for this date range, symbol may be delisted
# - SYT: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - KCR1V.HE: No data found, symbol may be delisted
# - 000157: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SYT: No data found for this date range, symbol may be delisted
# - CBS: No data found, symbol may be delisted
# - VIAB: No data found, symbol may be delisted
# - WIN.DE: No data found, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTL: No data found, symbol may be delisted
# - TNTE.AS: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - TYC: No data found for this date range, symbol may be delisted
# - 600751: No data found, symbol may be delisted
# - KCR1V.HE: No data found, symbol may be delisted
# - 000157: No data found, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - SNDK: No data found for this date range, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - TRCO: No data found, symbol may be delisted
# - SAB.L: No data found for this date range, symbol may be delisted
# - POM: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - ATC.AS: No data found, symbol may be delisted
# - BHI: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - 9984: No data found, symbol may be delisted
# - POM: No data found for this date range, symbol may be delisted
# - BHI: No data found for this date range, symbol may be delisted

# %% [markdown]
# #### A minor problem here is that some stocks are not available, due to either the symbol is delisted or the symbol doesn't match the stock ticker. We can deal with this problem by running a supplmental test, which uses web-searching to find the right ticker for these stocks. However, web-scraping is not the main concern of this project, and therefore here we only deal with the availble data at this point.

# %%
zipped = list(zip(headline, open_pr, close_pr))
dataframe = pd.DataFrame(zipped, columns=['Headline', 'Open_Price', 'Close_Price'])
print(dataframe)
# Out:
#                                               Headline  Open_Price  \
# 0    M&T Has "No Choice" But to See Hudson City Dea...   89.718083
# 1    Why Rumors of a PACCAR Acquisition by Volkswag...   47.673885
# 2                   All Eyes on DISH for Its Next Move   65.309998
# 3    Large Chiquita Shareholder Would Consider $15 Bid   82.220001
# 4    Industry Experts See Long Term Value Intact at...   22.000000
# ..                                                 ...         ...
# 731  FCC Expected to Announce Bidders for Spectrum ...   38.480000
# 732  FCC Expected to Announce Bidders for Spectrum ...   40.266148
# 733  FCC Expected to Announce Bidders for Spectrum ...   12.382095
# 734                  Pepco/Exelon Waiting for DC Mayor   18.579619
# 735  ACCC Review of Baker Hughes/Halliburton Procee...   31.282402
#
#      Close_Price
# 0      89.314529
# 1      46.735718
# 2      64.820000
# 3      83.000000
# 4      26.990000
# ..           ...
# 731    37.570000
# 732    40.089912
# 733    12.101563
# 734    18.840006
# 735    32.182293
#
# [736 rows x 3 columns]

# %%
#investpy.get_stock_historical_data('SNE', country = 'United States', from_date='27/01/2014', to_date='28/01/2014')['2014-01-27'

# %%
label = []
for i in range(len(dataframe)):
    if dataframe.iloc[i]['Open_Price'] < dataframe.iloc[i]['Close_Price']:
        label.append(1)
    else:
        label.append(0)

# %%
dataframe['label'] = label
dataframe
# Out:
#                                               Headline  Open_Price  \
# 0    M&T Has "No Choice" But to See Hudson City Dea...   89.718083
# 1    Why Rumors of a PACCAR Acquisition by Volkswag...   47.673885
# 2                   All Eyes on DISH for Its Next Move   65.309998
# 3    Large Chiquita Shareholder Would Consider $15 Bid   82.220001
# 4    Industry Experts See Long Term Value Intact at...   22.000000
# ..                                                 ...         ...
# 731  FCC Expected to Announce Bidders for Spectrum ...   38.480000
# 732  FCC Expected to Announce Bidders for Spectrum ...   40.266148
# 733  FCC Expected to Announce Bidders for Spectrum ...   12.382095
# 734                  Pepco/Exelon Waiting for DC Mayor   18.579619
# 735  ACCC Review of Baker Hughes/Halliburton Procee...   31.282402
#
#      Close_Price  label
# 0      89.314529      0
# 1      46.735718      0
# 2      64.820000      0
# 3      83.000000      1
# 4      26.990000      1
# ..           ...    ...
# 731    37.570000      0
# 732    40.089912      0
# 733    12.101563      0
# 734    18.840006      1
# 735    32.182293      1
#
# [736 rows x 4 columns]

# %%
#Division Line

# %%
import nltk                         # NLP toolbox
from os import getcwd
import pandas as pd                 # Library for Dataframes 
from nltk.corpus import twitter_samples 
import matplotlib.pyplot as plt     # Library for visualization
import numpy as np                  # Library for math functions

# %%
import re
import string
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

def process_headline(headline):
    """Process headline function.
    Input:
        headline: a string containing a headline
    Output:
        headlines_clean: a list of words containing the processed headline
    """
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    headline = re.sub(r'\$\w*', '', headline)
    # remove old style headline text "RT"
    headline = re.sub(r'^RT[\s]+', '', headline)
    # remove hyperlinks
    headline = re.sub(r'https?:\/\/.*[\r\n]*', '', headline)
    # remove hashtags
    # only removing the hash # sign from the word
    headline = re.sub(r'#', '', headline)
    # tokenize headlines using the package TweetTokenizer
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    headline_tokens = tokenizer.tokenize(headline)

    headlines_clean = []
    for word in headline_tokens:
        if (word not in stopwords_english and  # remove stopwords
                word not in string.punctuation):  # remove punctuation
            # headlines_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            headlines_clean.append(stem_word)

    return headlines_clean

tmpaccuracy = 0.6264224

import numpy as np

def build_freqs(headlines, ys):
    """Build frequencies.
    Input:
        headlines: a list of headlines
        ys: an m x 1 array with the sentiment label of each headline (either 0 or 1)
    Output:
        freqs: a dictionary mapping each (word, sentiment) pair to its frequency
    """
    # Convert np array to list since zip needs an iterable.
    # The squeeze is necessary or the list ends up with one element.
    # Also note that this is just a NOP if ys is already a list.
    yslist = np.squeeze(ys).tolist()

    # Start with an empty dictionary and populate it by looping over all headlines
    # and over all processed words in each headline.
    freqs = {}
    for y, headline in zip(yslist, headlines):
        for word in process_headline(headline):
            pair = (word, y)
            if pair in freqs:
                freqs[pair] += 1
            else:
                freqs[pair] = 1

    return freqs
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# UNQ_C3 FUNCTION: extract_features
def extract_features(headline, freqs, process_headline=process_headline):
    '''
    Input: 
        headline: a list of words for one headline
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_headline tokenizes, stems, and removes stopwords
    word_l = process_headline(headline)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    
    # loop through each word in the list of words
    for word in word_l:
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word,1),0)
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word,0),0)
        
    assert(x.shape == (1, 3))
    return x

# %%
# UNQ_C1 FUNCTION: sigmoid
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE ###
    # calculate the sigmoid of z
    h = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# UNQ_C2 FUNCTION: gradientDescent
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    '''

    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = -float(1)/m * (np.dot(np.transpose(y),np.log(h)) + np.dot(np.transpose(1-y),np.log(1-h)))

        # update the weights theta
        theta = theta - alpha/m * np.dot(np.transpose(x),(h-y))
        
    J = float(J[0])
    return J, theta

# %%
headline
# Out:
# ['M&T Has "No Choice" But to See Hudson City Deal to Conclusion, Expert Says',
#  'Why Rumors of a PACCAR Acquisition by Volkswagen Might Be More Than a Rumor',
#  'All Eyes on DISH for Its Next Move',
#  'Large Chiquita Shareholder Would Consider $15 Bid',
#  'Industry Experts See Long Term Value Intact at Hertz',
#  'Lack of Profits, High Price Tag, Increased Competition Dull Pandora Takeover Appeal',
#  "Source Sees 'Real Battle' in FCC Review of Time Warner Cable/Comcast",
#  '"Competitive Forces" Augur in Favor of Antitrust Clearance for Potential Staples/Office Depot Merger',
#  'CPUC is "Proactive Commission on Broadband" Says Former Commissioner, Talking About Time Warner Cable/Comcast',
#  'CPUC is "Proactive Commission on Broadband" Says Former Commissioner, Talking About Time Warner Cable/Comcast',
#  'Will Sprint Become the Low Cost Carrier or the High Speed Servicer?',
#  'Game Changing Zillow-Trulia Merger Unlikely to Be Held Back by FTC Query',
#  'CPUC Had Prepared Hard Line on T-Mobile/AT&T in 2011 - Meet the Commission Reviewing TWC/Comcast',
#  'Home Depot Data Breach Costs Rise To $500 Mil.',
#  'Congress Contemplates Additional Steps on Tax Inversions',
#  'Congress Contemplates Additional Steps on Tax Inversions',
#  'Congress Contemplates Additional Steps on Tax Inversions',
#  'Molson Coors is Not Likely Next Constellation',
#  'Tax Inversion Deals Bruised But Not Mortally Wounded',
#  'Tax Inversion Deals Bruised But Not Mortally Wounded',
#  'Tax Inversion Deals Bruised But Not Mortally Wounded',
#  'Apple Pay Keeps Visa, MasterCard On Track',
#  'Apple Pay Keeps Visa, MasterCard On Track',
#  'Apple Pay Keeps Visa, MasterCard On Track',
#  'Fannie, Freddie Investors Seek Lifeline After Court Ruling',
#  'Gilead Injunction Against AbbVie May Hinge on Unbraiding First Amendment Defense',
#  'Gilead Injunction Against AbbVie May Hinge on Unbraiding First Amendment Defense',
#  'Investors Sort Through Potential Winners, Losers, as DOT Preps Tank Car Safety Rules',
#  'Senate, House Staffer Meet with Fannie, Freddie Investors but Appear Lukewarm',
#  'Zwanziger Likely Has Financial Backing for Alere Bid, Source Says',
#  "Insurers Actions May Force Sears' Vendors to Take Proactive Steps",
#  'Unlikely Balfour in Merger Talks in Near Term, Industry Insider Says',
#  'Internet of Things May Drive Microchip to Increased Bid for CSR',
#  'Does Treasury-FHFA Conflict of Interest Leave Room for Appeal by FNMA Investors?',
#  'AT&T Differentiates Itself From Comcast, Knocks at Netflix in FCC Response',
#  'AT&T Differentiates Itself From Comcast, Knocks at Netflix in FCC Response',
#  'New Chiquita Offer Fails to Impress',
#  'CPUC Head Replacement Opens Question About Comcast Review',
#  'CPUC Head Replacement Opens Question About Comcast Review',
#  'SandRidge Should Narrow Focus, Likely a Takeover Target',
#  "Credit Insurers Appear Unimpressed with Sears' Latest Financing",
#  'FCC Stops Clock on TWC/Comcast and DIRECTV/AT&T Reviews',
#  'FCC Stops Clock on TWC/Comcast and DIRECTV/AT&T Reviews',
#  'With Falling Oil Price, Battered Stock Price, Civeo Accedes to JANA',
#  'Pepsi Deal Possibly Harbinger of Bigger Move on SodaStream',
#  'Pepsi Deal Possibly Harbinger of Bigger Move on SodaStream',
#  'Fannie, Freddie Dispute Could Rest On Congressional Intent',
#  'Covidien/Medtronic Deal Moves Ahead on Calculated Merits',
#  'Visa, MasterCard Targeted in Apple Pay Brouhaha',
#  'Visa, MasterCard Targeted in Apple Pay Brouhaha',
#  'Visa, MasterCard Targeted in Apple Pay Brouhaha',
#  'Major Delay Seen in New Tank Car Safety Rules',
#  "Uncertain Way Forward for Angie's List",
#  'Sears Proposed REIT Move May Not Stem Woes',
#  'Congress Maps New Fannie, Freddie Fix',
#  'Genworth Remains Committed to Long Term Care',
#  'Spirit Fundamentals Drive Bid Interest and Potential Synergies',
#  'Trial Lawyers Trail Ocwen Regulators',
#  'How will the Keurig - Coca-Cola Relationship Develop?',
#  'Actavis/Allergan Deal Fuels Debate Over Tax Inversions',
#  'Halliburton/Baker Hughes Deal Expected to Complete',
#  'Halliburton/Baker Hughes Deal Expected to Complete',
#  'Sears Saga Continues',
#  'Third Point Sees Considerable Upside in Amgen Breakup',
#  'Beef Shortage Will Underpin Zoetis Revenue Growth',
#  'Songbird Likely to See Increased Offer, Experts Agree',
#  'Wheeler a Centrist on Net Neutrality, Expert Says',
#  'Wheeler a Centrist on Net Neutrality, Expert Says',
#  'Pershing Square Seeks To Block Governments Move In Fannie/Freddie Case',
#  'Zillow, Trulia Set to Shake Up Industry Combined or Separately',
#  'North Dakota to Vote on New Oil Safety Rules',
#  'Separate Antitrust Suits Could Pose Significant Legal Liability for Visa and MasterCard',
#  'Separate Antitrust Suits Could Pose Significant Legal Liability for Visa and MasterCard',
#  'Mattel Could be the Right Suitor for DreamWorks Animation',
#  'Keurig Transitions from Patent Model to Trademark Model While Coke Waits in the Wings',
#  'Dominant Content Provider Should Oppose Net Neutrality, Study Says',
#  'Dominant Content Provider Should Oppose Net Neutrality, Study Says',
#  'Pressure Building in California on Time Warner Cable/Comcast Merger Review',
#  'Fairholme Takes Third Shot in Fight Over Fannie/Freddie Shares',
#  'Judge Asks if Iowa Fannie Mae Case Is as Simple as "Read the Statute?"',
#  'Updates from Continental Western v FHFA Today (Dec 16) in Federal Court',
#  'Halliburton/Baker Hughes Deal Likely to Spur Development of Third Tier 1 Player',
#  'Halliburton/Baker Hughes Deal Likely to Spur Development of Third Tier 1 Player',
#  'Coke Needs Transition from Growth to Cost Focus, Activist Says',
#  'CPUC Shift Challenges Time Warner Cable/Comcast Merger',
#  'Ventas/ARC Healthcare Merger Moving Ahead',
#  'Ventas/ARC Healthcare Merger Moving Ahead',
#  'Fannie/Freddie Investors Map Course Toward High Court',
#  'CNBC Move Highlights Questions Over Nielsen Growth',
#  'Next "Big Short" Involves Invalidating Pharma Patents',
#  'Next "Big Short" Involves Invalidating Pharma Patents',
#  'Cubist Patent Upheld by Judge More Important than Four Invalidated',
#  'Playbook on Hold for Ackman/Valeant Type Partnership; Valeant May Look at Endo',
#  'Title II Issues Divide FCC, Foretell Legal Challenges',
#  'Title II Issues Divide FCC, Foretell Legal Challenges',
#  'Dollar General Questions Unproven Antitrust Measure',
#  'Dollar General Questions Unproven Antitrust Measure',
#  'Former FCC Commissioner Warns on Title II, Says Tech Supporters Will Regret It',
#  'Former FCC Commissioner Warns on Title II, Says Tech Supporters Will Regret It',
#  'Express Inc. Healthy Despite Failed LBO',
#  'Congress Unlikely to Act on Fannie/Freddie Reform Despite Proposals',
#  'Court Ruling Boosts Fannie/Freddie Investors',
#  "Activists Hope FCC's New Broadband Definition Hampers Comcast Merger Review",
#  "Pricing Pressures Loom for Dick's Sporting Goods",
#  'Baker Hughes/Halliburton May Divest Less Than Planned',
#  'Baker Hughes/Halliburton May Divest Less Than Planned',
#  'Kroger Should Grow with Bolt-Ons not Winn-Dixie Purchase, Say Experts',
#  'Pfizer-Hospira Deal Could See FTC Focus on Future Competition',
#  'CPUC Appears Ready to Rule on Time Warner Cable/Comcast',
#  '3D Systems Faces Slower Growth, Possible Takeover',
#  'BPs Financial Woes Put Company at Center of Merger Rumors',
#  'Motorola Solutions Appeals to Variety of Buyers While Facing Declining Business Trends',
#  'AT&T/DIRECTV Merger Presents Horizontal Overlaps, Advocacy Group Says',
#  'Tootsie Roll Appears Ready for Takeover',
#  'Orbitz/Expedia Could Test Antitrust Measure',
#  'Peabody Target of Takeover Speculation as it Positions for Growing World Energy Consumption',
#  'CPUC Has Jurisdiction to Deny Time Warner Cable/Comcast Merger Says Source',
#  'Sysco Fight with FTC Could be Brief',
#  "Tornier/Wright Medical Overlap in Mini Plates Could be Drawing Regulators' Interest",
#  'Vibrant Competition Bodes Well for Staples/Office Depot Antitrust Review',
#  'Will Sanctions Impact Russian Antitrust Review of Halliburton-Baker Hughes Merger',
#  'Will Sanctions Impact Russian Antitrust Review of Halliburton-Baker Hughes Merger',
#  'FCC Approval for DIRECTV, AT&T Deal Unlikely to See Significant Conditions',
#  'Sysco Prospects Good in FTC Merger Tilt',
#  'Discovery Communications Combination with Fox Offers Scale, Leverage, and Cost Cutting',
#  'Exelon Sweetens the Pot in Bid to Win Pepco Deal',
#  'Exelon Sweetens the Pot in Bid to Win Pepco Deal',
#  'FTC Aims for Quick Knock-Out of Sysco-US Foods Deal',
#  'Large Pharma Likely to Dominate Biosimilar Growth Opportunity',
#  'Large Pharma Likely to Dominate Biosimilar Growth Opportunity',
#  'NXP-Freescale Acquisition Likely Triggers Second Request',
#  'Defense Business Could Limit Options in NXP-Freescale Deal',
#  'Halliburton-Baker Hughes Asset Sales Likely Halved',
#  'Halliburton-Baker Hughes Asset Sales Likely Halved',
#  'Tenet/USPI to Test Antitrust Regulators',
#  'SS&C Resets Clock on Advent Deal with "Pull and Refile"',
#  'Online Overlap and Supplier Issues Could be Focus of Expedia-Orbitz Second Request',
#  "Pandora's Challenges Persist, Though It Could Fit with Google Play",
#  'Broadband Definition at Issue in CPUC Evaluation of Comcast-Time Warner Cable',
#  'Aspen Seen as Persistent Reinsurance Industry Takeover Play',
#  'Sysco-US Foods Win Interim Court Victory, Appear to Have Stronger Case',
#  'UnitedHealth-Catamaran Deal Pressures Pharma Companies',
#  'Siemens Wrestles with Divestiture for Dresser Acquisition',
#  'Comcast, AT&T Reviews Face Delay as FCC Likely to Lose CBS Case',
#  'Comcast, AT&T Reviews Face Delay as FCC Likely to Lose CBS Case',
#  'UnitedHealth-Catamaran Unlikely to Lose Cigna Contract',
#  'Time Warner Cable-Comcast Deal Challenged in California',
#  "Teva's Auspex Acquisition Leaves Open Questions on SD-809",
#  'Time Warner Cable-Comcast Deal Provokes High-Stakes Guessing Game in California',
#  'Interview: CBOE Exec Talks Product Strategy',
#  'Comcast/Time Warner Cable Merger May Face Horizontal Theory of Harm',
#  'Teva Has Plan for Mylan Antitrust Issues',
#  'Teva Has Plan for Mylan Antitrust Issues',
#  'Sysco Case Gets Support from Performance Food Group',
#  'Expedia-Orbitz Review by EC Could Lead to Remedy',
#  'Staples/Office Depot Deal Buoyed by Amazon Business',
#  'Staples/Office Depot Deal Buoyed by Amazon Business',
#  'M&T Bank-Hudson City Face Risks of Further Delay',
#  'US Foods Remains a Target if FTC Prevails Against Sysco Acquisition',
#  'FTC v. Sysco: Updates from the Proceedings',
#  'FTC v. Sysco: Updates from the Proceedings',
#  'FTC to Call PFGs CEO as Hostile Witness in Sysco Trial',
#  'FTC to Call PFGs CEO as Hostile Witness in Sysco Trial',
#  'PartnerRe Shareholder Vote for AXIS Capital Deal in Doubt',
#  'PartnerRe Shareholder Vote for AXIS Capital Deal in Doubt',
#  'PartnerRe Shareholder Vote for AXIS Capital Deal in Doubt',
#  'FTC Grills Performance Food Group CEO on Early Affidavit',
#  'FTC Grills Performance Food Group CEO on Early Affidavit',
#  'FTC Economist Labels Sysco-US Foods Merger Anti-Competitive',
#  'FTC Economist Labels Sysco-US Foods Merger Anti-Competitive',
#  'Syscos DeLaney Will Try to Save Troubled US Foods Deal',
#  'Syscos DeLaney Will Try to Save Troubled US Foods Deal',
#  'Thursday:  FTC v. Sysco Updates from the Proceedings',
#  'Thursday:  FTC v. Sysco Updates from the Proceedings',
#  'JANA Pushes Case for Qualcomm Separation',
#  'Sysco, US Foods Execs Decry Loss of Customers, Competition from Regionals',
#  'Sysco, US Foods Execs Decry Loss of Customers, Competition from Regionals',
#  'Biosimilar Financial Opportunity Less than Implied by Activity',
#  'Biosimilar Financial Opportunity Less than Implied by Activity',
#  'Biosimilar Financial Opportunity Less than Implied by Activity',
#  'Sysco-US Foods Synergies Could Reach $1 Billion Court Testimony Shows',
#  'Sysco-US Foods Synergies Could Reach $1 Billion Court Testimony Shows',
#  'Sysco Makes Inroads in Antitrust Case Tuesday',
#  'Sysco Makes Inroads in Antitrust Case Tuesday',
#  'EXOR Likely to Prevail with PartnerRe Contested Offer',
#  'EXOR Likely to Prevail with PartnerRe Contested Offer',
#  'EXOR Likely to Prevail with PartnerRe Contested Offer',
#  'Dueling Economists End Sysco Antitrust Hearing',
#  'Dueling Economists End Sysco Antitrust Hearing',
#  'Cogent CEO Says Considering Lawsuit Against AT&T',
#  'Cogent CEO Says Considering Lawsuit Against AT&T',
#  'Cogent CEO Says Considering Lawsuit Against AT&T',
#  'Cogent CEO Says Considering Lawsuit Against AT&T',
#  'Proliferation of Drug Deals Could Prolong Antitrust Reviews',
#  'Proliferation of Drug Deals Could Prolong Antitrust Reviews',
#  'Proliferation of Drug Deals Could Prolong Antitrust Reviews',
#  'FCCs AT&T-DirecTV Review Focusing on Interconnection Abuses',
#  'FCCs AT&T-DirecTV Review Focusing on Interconnection Abuses',
#  'FCCs AT&T-DirecTV Review Focusing on Interconnection Abuses',
#  'FCCs AT&T-DirecTV Review Focusing on Interconnection Abuses',
#  'FCC Looks to Complete Work on AT&T-DirecTV',
#  'CVS-Omnicare Deal to Get Close Scrutiny, Long Review',
#  'Tiffany Could Positively Surprise, Remains Target of Speculation',
#  'Charter-Time Warner Cable Deal to Draw Scrutiny of Vertical Effects',
#  'Preview:  FTC v. Sysco Closing Oral Arguments Thursday Afternoon',
#  'Preview:  FTC v. Sysco Closing Oral Arguments Thursday Afternoon',
#  'China-Gazprom Deal May Be Key to How Shell-BG Merger Evolves',
#  'Live Updates: Oral Arguments in FTC v. Sysco Today May 28',
#  'Live Updates: Oral Arguments in FTC v. Sysco Today May 28',
#  "Sysco Antitrust Hearing Ends with Judge Poking Holes in Both Sides' Arguments",
#  "Sysco Antitrust Hearing Ends with Judge Poking Holes in Both Sides' Arguments",
#  'Inside the Mind of One of M&As Top Funds',
#  'Inside the Mind of One of M&As Top Funds',
#  'Business-to-Business Customers Appear Unvexed by Staples-Office Depot Combo',
#  'Business-to-Business Customers Appear Unvexed by Staples-Office Depot Combo',
#  'Business-to-Business Customers Appear Unvexed by Staples-Office Depot Combo',
#  'Steris Acquisition of Synergy Health Uncertain After FTC Challenge',
#  'AT&T-DirecTV Merger Approval Advancing But No Conditions Set',
#  'Abbott Holds Critical Stake in Teva-Mylan Merger Tilt',
#  'Abbott Holds Critical Stake in Teva-Mylan Merger Tilt',
#  'Abbott Holds Critical Stake in Teva-Mylan Merger Tilt',
#  "Will Brink's Margin Gains Stave Off Activist Fight?",
#  'Chinese Companies Move into Hollywood via Financing and Acquisitions',
#  'FTC Tests Future Markets Theory with Steris-Synergy Health Challenge',
#  'FCC Approval of AT&T-DirecTV Still Needs Agreement on Tough Issues',
#  'FCC Approval of AT&T-DirecTV Still Needs Agreement on Tough Issues',
#  'FCC Approval of AT&T-DirecTV Still Needs Agreement on Tough Issues',
#  'Exelon-Pepco Merger to Face Critics in DC',
#  'Exelon-Pepco Merger to Face Critics in DC',
#  'Analyst Sees Leverage in Combined Wright Medical-Tornier',
#  'Cogent CEO Sees "Over-the-Top" Dominating FCC Order for AT&T-DirecTV',
#  'Cogent CEO Sees "Over-the-Top" Dominating FCC Order for AT&T-DirecTV',
#  'Teva Plots Path Around Mylan Defenses',
#  'Teva Plots Path Around Mylan Defenses',
#  'Teva Plots Path Around Mylan Defenses',
#  'Steris Seen Settling With FTC to Save Tax Inversion',
#  'EXOR Exhibits Edge in PartnerRe Roadshow',
#  'EXOR Exhibits Edge in PartnerRe Roadshow',
#  'EXOR Exhibits Edge in PartnerRe Roadshow',
#  'Court Investigator Critical to Stay of Claims Against Caesars Entertainment',
#  'Slight Delay Seen in FCC Approval of AT&T/DirecTV Merger',
#  'Court Ruling Likely Kills Sysco/US Foods Deal',
#  'Court Ruling Likely Kills Sysco/US Foods Deal',
#  'Court Ruling Likely Kills Sysco/US Foods Deal',
#  'CVS/Target Deal to Impact PBMs and Distributors',
#  'CVS/Target Deal to Impact PBMs and Distributors',
#  'CVS/Target Deal to Impact PBMs and Distributors',
#  'CVS/Target Deal to Impact PBMs and Distributors',
#  'AT&T Fails Interconnection Test Advocacy Group Tells FCC',
#  'AT&T Fails Interconnection Test Advocacy Group Tells FCC',
#  'Health Insurer Consolidation Invites Regulatory Reviews at Multiple Levels',
#  'Health Insurer Consolidation Invites Regulatory Reviews at Multiple Levels',
#  'Health Insurer Consolidation Invites Regulatory Reviews at Multiple Levels',
#  'Health Insurer Consolidation Invites Regulatory Reviews at Multiple Levels',
#  'Health Insurer Consolidation Invites Regulatory Reviews at Multiple Levels',
#  'Dish Auction Maneuver Could Color FCC Review of Potential T-Mobile Deal',
#  'Dish Auction Maneuver Could Color FCC Review of Potential T-Mobile Deal',
#  'Dish Auction Maneuver Could Color FCC Review of Potential T-Mobile Deal',
#  'Dish Auction Maneuver Could Color FCC Review of Potential T-Mobile Deal',
#  'FCC Decision on AT&T-DirecTV Merger Doubtful this Week',
#  'Sysco/US Foods Opinion Bolsters APWUs Arguments Against Staples/Office Depot',
#  'Sysco/US Foods Opinion Bolsters APWUs Arguments Against Staples/Office Depot',
#  "Exclusive:  Interview with the FTC's Stephen Weissman",
#  "Exclusive:  Interview with the FTC's Stephen Weissman",
#  "Exclusive:  Interview with the FTC's Stephen Weissman",
#  'Halliburton Asset Sales Move Slowly Amid Uncertainties',
#  'Halliburton Asset Sales Move Slowly Amid Uncertainties',
#  'FCC Still a Few Days from AT&T-DirecTV Decision',
#  'New Hurdle Seen Slowing Exelon-Pepco Merger',
#  'New Hurdle Seen Slowing Exelon-Pepco Merger',
#  'AT&T-DirecTV Merger Advances Slowly Through FCC Process',
#  'Aetna-Humana Deal Faces Maze of Regulators',
#  'Aetna-Humana Deal Faces Maze of Regulators',
#  'Aetna-Humana Deal Faces Maze of Regulators',
#  'Aetna-Humana Deal Faces Maze of Regulators',
#  'Aetna-Humana Deal Faces Maze of Regulators',
#  'Charter-TWC-Bright House Merger Poses Another Test for FCC',
#  'Charter-TWC-Bright House Merger Poses Another Test for FCC',
#  'Charter-TWC-Bright House Merger Poses Another Test for FCC',
#  'Pep Boys Sale Possible as Operations Demand Improvements',
#  'Pep Boys Sale Possible as Operations Demand Improvements',
#  'PartnerRe Looked Likely to Face Adverse Proxy Recommendation',
#  'PartnerRe Looked Likely to Face Adverse Proxy Recommendation',
#  'FCC Could Rule as Early as Wednesday on AT&T-DirecTV Merger',
#  'No Decision Yet as FCC Mulls Final Conditions in AT&T-DirecTV Merger',
#  'Sweetened PartnerRe-AXIS Terms Unlikely to Swing Vote',
#  'Sweetened PartnerRe-AXIS Terms Unlikely to Swing Vote',
#  'Paulson Poised as Pivotal Teva-Mylan Shareholder',
#  'Paulson Poised as Pivotal Teva-Mylan Shareholder',
#  'Anadarko Navigates Oil and Gas Downturn',
#  'Anadarko Navigates Oil and Gas Downturn',
#  'State Regulators Eye Too Big To Fail for Anthem/Cigna',
#  'State Regulators Eye Too Big To Fail for Anthem/Cigna',
#  'State Regulators Eye Too Big To Fail for Anthem/Cigna',
#  'State Regulators Eye Too Big To Fail for Anthem/Cigna',
#  'State Regulators Eye Too Big To Fail for Anthem/Cigna',
#  'Does the Spike in Housing Portend Homebuilder M&A?',
#  'Does the Spike in Housing Portend Homebuilder M&A?',
#  'Does the Spike in Housing Portend Homebuilder M&A?',
#  'Does the Spike in Housing Portend Homebuilder M&A?',
#  'EPA Rules Spur TECO to Seek Buyer',
#  'EPA Rules Spur TECO to Seek Buyer',
#  'EPA Rules Spur TECO to Seek Buyer',
#  'FCC Dispute Could Delay "Shot Clock" Start on Charter Merger',
#  'Biosimilars Seen Fueling Next Wave of Pharma Deals',
#  'Biosimilars Seen Fueling Next Wave of Pharma Deals',
#  'Centene-Health Net Merger Agreement Speaks to Heated M&A Climate',
#  'Centene-Health Net Merger Agreement Speaks to Heated M&A Climate',
#  'AXIS Capital Continues to Invoke Takeover Speculation',
#  'AXIS Capital Continues to Invoke Takeover Speculation',
#  'AXIS Capital Continues to Invoke Takeover Speculation',
#  'AT&T, Verizon Likely Winners Again at Next FCC Spectrum Auction',
#  'AT&T, Verizon Likely Winners Again at Next FCC Spectrum Auction',
#  'AT&T, Verizon Likely Winners Again at Next FCC Spectrum Auction',
#  'AT&T, Verizon Likely Winners Again at Next FCC Spectrum Auction',
#  'AT&T, Verizon Likely Winners Again at Next FCC Spectrum Auction',
#  'Impact of Charter Merger Already Raising Concerns of Interest Groups in California',
#  'Impact of Charter Merger Already Raising Concerns of Interest Groups in California',
#  'Judge in Maryland Hamlet Holds Key to Exelon-Pepco Closing',
#  'Judge in Maryland Hamlet Holds Key to Exelon-Pepco Closing',
#  "Will M&T Bank's Compliance Efforts Satisfy the Federal Reserve?",
#  'Court Weighs FTC Theory on Future Competition',
#  'Live Updates: FTC v. Steris in Federal Court in Cleveland',
#  'Definitional Question Haunts Halliburton-Baker Hughes Merger Review',
#  'Definitional Question Haunts Halliburton-Baker Hughes Merger Review',
#  'Definitional Question Haunts Halliburton-Baker Hughes Merger Review',
#  'Synergy CEO Takes Hot Seat in Steris Antitrust Hearing',
#  'Doubts Raised on Synergys Abandonment of X-Ray After Steris Deal',
#  'Big Telecom M&A on Pause',
#  'Big Telecom M&A on Pause',
#  'Big Telecom M&A on Pause',
#  'Big Telecom M&A on Pause',
#  'Steris CEO Takes the Stand to Save Synergy Deal',
#  'Staples-Office Depot Deal Still Facing Stringent Anti-Trust Review',
#  'Staples-Office Depot Deal Still Facing Stringent Anti-Trust Review',
#  'Depomed Faces Legal Hurdles in Blocking Horizon Pharma Bid',
#  'Lumentum is More Acquirer than Target, Company Executive Says',
#  'Lumentum is More Acquirer than Target, Company Executive Says',
#  'Lumentum is More Acquirer than Target, Company Executive Says',
#  'Headwinds, Not Tradewinds, Greet NextEra-Hawaiian Electric Merger Efforts',
#  'Headwinds, Not Tradewinds, Greet NextEra-Hawaiian Electric Merger Efforts',
#  'Shell-BG Merger May Benefit from Brazils Ongoing Corruption Scandal',
#  'AT&T May Face Choice Between Dividend and Credit Rating in a Few Years',
#  'AT&T May Face Choice Between Dividend and Credit Rating in a Few Years',
#  'AT&T May Face Choice Between Dividend and Credit Rating in a Few Years',
#  'Choices Facing Exelon-Pepco Suggest Significant Delay',
#  'Choices Facing Exelon-Pepco Suggest Significant Delay',
#  'FTC Appears to Have Strong Case as Steris-Synergy Health Await Ruling',
#  'EMC-VMware Resolution Unlikely to Follow Seagate-Veritas Precedent',
#  'EMC-VMware Resolution Unlikely to Follow Seagate-Veritas Precedent',
#  'Housing Advocates Praise M&T Bank-Hudson City Merger Despite Criminal Probe',
#  'Will Staples and Office Depot Survive Without Merger?',
#  'Will Staples and Office Depot Survive Without Merger?',
#  'Qualcomm Still Contemplating Split',
#  'Emera-TECO Merger Highlights Utility Sector Appeal',
#  'Emera-TECO Merger Highlights Utility Sector Appeal',
#  'Emera-TECO Merger Highlights Utility Sector Appeal',
#  'Emera-TECO Merger Highlights Utility Sector Appeal',
#  'Emera-TECO Merger Highlights Utility Sector Appeal',
#  'APWU to Stir More Trouble for Staples-Office Depot Deal',
#  'Quick Clearance Seen for XPO Logistics-Con-way Deal',
#  'Single-Buyer Mandate Challenges Halliburton-Baker Hughes Merger',
#  'Single-Buyer Mandate Challenges Halliburton-Baker Hughes Merger',
#  'Woodside-Oil Search Deal Appears Ill-Fated',
#  "NextEra Calls Hawaii's Bluff on Merger",
#  "NextEra Calls Hawaii's Bluff on Merger",
#  'Exelon to Press D.C. to Reconsider Pepco Merger',
#  'Exelon to Press D.C. to Reconsider Pepco Merger',
#  'Exelon to Press D.C. to Reconsider Pepco Merger',
#  'What Is Next for Woodside-Oil Search?',
#  'What Is Next for Woodside-Oil Search?',
#  'SoftBank Probably Needs to Give Sprint Further Infusion of Capital',
#  'SoftBank Probably Needs to Give Sprint Further Infusion of Capital',
#  'SoftBank Probably Needs to Give Sprint Further Infusion of Capital',
#  'DoD Raises Security Concerns in NextEras Hawaii Merger',
#  'DoD Raises Security Concerns in NextEras Hawaii Merger',
#  'Is There a Deal Ahead for Ethan Allen?',
#  'Is There a Deal Ahead for Ethan Allen?',
#  'Interview:  Views on Woodside-Oil Search',
#  'Interview:  Views on Woodside-Oil Search',
#  'Interview:  Views on Woodside-Oil Search',
#  'Senate Hearing Previews Antitrust Reviews for Aetna and Anthem Deals',
#  'Senate Hearing Previews Antitrust Reviews for Aetna and Anthem Deals',
#  'Senate Hearing Previews Antitrust Reviews for Aetna and Anthem Deals',
#  'Senate Hearing Previews Antitrust Reviews for Aetna and Anthem Deals',
#  'Senate Hearing Previews Antitrust Reviews for Aetna and Anthem Deals',
#  'Clock Ticking Down on M&T-Hudson City Merger',
#  'Staples-Office Depot Resolution with FTC Remains Uncertain',
#  'Staples-Office Depot Resolution with FTC Remains Uncertain',
#  'FTC Loses Challenge to Steris Merger',
#  'Hostile Bid for K+S by Potash Should See Few German Hurdles',
#  'Hostile Bid for K+S by Potash Should See Few German Hurdles',
#  'RSA Insurance Remains in Play',
#  'RSA Insurance Remains in Play',
#  'Frustrated Democrats Seek Public Shaming to Curb Tax Inversions',
#  'Frustrated Democrats Seek Public Shaming to Curb Tax Inversions',
#  'Frustrated Democrats Seek Public Shaming to Curb Tax Inversions',
#  'Frustrated Democrats Seek Public Shaming to Curb Tax Inversions',
#  'Purported Sales of Verizon and AT&T Enterprise Businesses May Prove Challenging',
#  'Purported Sales of Verizon and AT&T Enterprise Businesses May Prove Challenging',
#  'Charter Merger Proceedings Progressing at FCC and in California',
#  'Charter Merger Proceedings Progressing at FCC and in California',
#  'Antitrust Concerns May Fetter Konecranes-Terex Merger',
#  'Antitrust Concerns May Fetter Konecranes-Terex Merger',
#  'Halliburton-Baker Hughes Deal Walks Fine Line',
#  'Halliburton-Baker Hughes Deal Walks Fine Line',
#  'Halliburton-Baker Hughes Deal Walks Fine Line',
#  'Halliburton-Baker Hughes Deal Walks Fine Line',
#  'City Government of D.C. Wants Time to Consider Exelon-Pepco Settlement',
#  'City Government of D.C. Wants Time to Consider Exelon-Pepco Settlement',
#  'Exelon-Pepco Reconsideration Battle Heats Up Next Week',
#  'Exelon-Pepco Reconsideration Battle Heats Up Next Week',
#  'Bill Would Bar Second FTC Chance to Block Mergers',
#  'NextEra-Hawaiian Electric Merger Recalls Hawaiian Telecom Fiasco',
#  'NextEra-Hawaiian Electric Merger Recalls Hawaiian Telecom Fiasco',
#  'Skinny Bundle Propels Short Selling of Cable and Satellite Providers',
#  'Skinny Bundle Propels Short Selling of Cable and Satellite Providers',
#  'Skinny Bundle Propels Short Selling of Cable and Satellite Providers',
#  'Skinny Bundle Propels Short Selling of Cable and Satellite Providers',
#  'Telecoms Advised to Wind Down Deal Talks by December',
#  'Telecoms Advised to Wind Down Deal Talks by December',
#  'Telecoms Advised to Wind Down Deal Talks by December',
#  'Telecoms Advised to Wind Down Deal Talks by December',
#  'Telecoms Advised to Wind Down Deal Talks by December',
#  "Kohl's Appears to be LBO Candidate",
#  "Kohl's Appears to be LBO Candidate",
#  "Kohl's Appears to be LBO Candidate",
#  'Settlement Puts Exelon-Pepco Merger on Track for Year-End Completion',
#  'Settlement Puts Exelon-Pepco Merger on Track for Year-End Completion',
#  'Timing Tricky for Charter-Time Warner Cable Review',
#  'Timing Tricky for Charter-Time Warner Cable Review',
#  'Baker Hughes-Halliburton Merger Seen Moving Forward',
#  'Baker Hughes-Halliburton Merger Seen Moving Forward',
#  'Baker Hughes-Halliburton Merger Seen Moving Forward',
#  'Baker Hughes-Halliburton Merger Seen Moving Forward',
#  'Proposed Pepco-Exelon Deal Must Return to State Regulators',
#  'Proposed Pepco-Exelon Deal Must Return to State Regulators',
#  'Suncor Bid for Canadian Oil Sands Could Spur Counteroffers',
#  'European Commission Review Clouds Staples-Office Depot Deal',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'Legacy Big Data Players Face Potential Disruption from Hadoop and Spark Startups',
#  'EU Regulators Await Information from Halliburton and Baker Hughes',
#  'EU Regulators Await Information from Halliburton and Baker Hughes',
#  'EU Regulators Await Information from Halliburton and Baker Hughes',
#  'Competition Regulators to Untangle EMC/Dell Merger',
#  'Competition Regulators to Untangle EMC/Dell Merger',
#  'Konecranes-Terex Likely to Offload German Assets to Clear Deal',
#  'Broadcast Group Asks FCC to Delay Time Warner Cable-Charter MergerÂ\xa0',
#  'Broadcast Group Asks FCC to Delay Time Warner Cable-Charter MergerÂ\xa0',
#  'Broadcast Group Asks FCC to Delay Time Warner Cable-Charter MergerÂ\xa0',
#  'Broadcast Group Asks FCC to Delay Time Warner Cable-Charter MergerÂ\xa0',
#  'Approval of Pepco/Exelon Deal Seen Slipping into 2016',
#  'Approval of Pepco/Exelon Deal Seen Slipping into 2016',
#  'Office Depot-Staples Review in Europe Remains in Investigation Stage',
#  'Could Florida Case Come Back to Haunt Hawaiian Electric-NextEra Merger?',
#  'Could Florida Case Come Back to Haunt Hawaiian Electric-NextEra Merger?',
#  'BorgWarner Moves Ahead with Remy Tie-up',
#  'Baker Hughes-Halliburton Deal Drags Through Regulatory Probes',
#  'Baker Hughes-Halliburton Deal Drags Through Regulatory Probes',
#  'Bribery Scandal Could Cloud Diebold Deliberations',
#  'Bribery Scandal Could Cloud Diebold Deliberations',
#  'CFIUS Could Delay Western Digitals Closing of SanDisk Acquisition',
#  'Suncor Bid for Canadian Oil Sands Comes Amid Political Upheaval',
#  'Hadoop M&A May Begin Soon',
#  'Hadoop M&A May Begin Soon',
#  'Hadoop M&A May Begin Soon',
#  'Hadoop M&A May Begin Soon',
#  'Hadoop M&A May Begin Soon',
#  'Hadoop M&A May Begin Soon',
#  'Chip Equipment Makers Lam Research and KLA-Tencor Can Expect Long Antitrust Review',
#  'Chip Equipment Makers Lam Research and KLA-Tencor Can Expect Long Antitrust Review',
#  'Opposition Remains Firm in Hawaiian Electric-NextEra Merger',
#  'Opposition Remains Firm in Hawaiian Electric-NextEra Merger',
#  'Diebold Acquisition of Wincor Nixdorf Could Need Divestments in Southern Europe',
#  'FedEx-TNT Deal Faces “Strong Opposition”\x9d in Brazil',
#  'Optimism Surfaces in Staples-Office Depot Deal',
#  'Optimism Surfaces in Staples-Office Depot Deal',
#  'Walgreens Deal Invites Antitrust Scrutiny',
#  'Walgreens Deal Invites Antitrust Scrutiny',
#  'Walgreens Deal Invites Antitrust Scrutiny',
#  'D.C. Regulators Set Brief Schedule to Settle Pepco-Exelon Deal',
#  'D.C. Regulators Set Brief Schedule to Settle Pepco-Exelon Deal',
#  'ACCC Struggles with "Economy of Scope" Issue in Halliburton-Baker Hughes Merger',
#  'ACCC Struggles with "Economy of Scope" Issue in Halliburton-Baker Hughes Merger',
#  'Lam Counsel Sees No Delays with KLA-Tencor Merger',
#  'Lam Counsel Sees No Delays with KLA-Tencor Merger',
#  'UPS Calls for In-depth Review of FedEx-TNT Merger',
#  'UPS Calls for In-depth Review of FedEx-TNT Merger',
#  'Fresh Market: Is a Going-Private Transaction Likely?',
#  'Interview:\xa0 AXIS Capital Looks for Combined Ratio Improvement',
#  'No Smoking Gun in APWUs Latest Staples-Office Depot Report',
#  'Tracking Stock Leaves EMC/Dell Deal in Virtual Confusion',
#  'Tracking Stock Leaves EMC/Dell Deal in Virtual Confusion',
#  'Bass Pro-Cabela Rivalry Clouds Combination',
#  'GE-Electrolux Provides Rare Court Antitrust Test',
#  'GE-Electrolux Provides Rare Court Antitrust Test',
#  'GE-Electrolux Provides Rare Court Antitrust Test',
#  'Viavi Solutions No Longer in Active Sale Mode',
#  'Viavi Solutions No Longer in Active Sale Mode',
#  'Electrolux Lawyers Diminish Governments Antitrust Case',
#  'Electrolux Lawyers Diminish Governments Antitrust Case',
#  'Electrolux Lawyers Diminish Governments Antitrust Case',
#  'Apache is an Attractive Acquisition Candidate',
#  'Widening Arb Spread Stirs Baker Hughes-Halliburton Doubts',
#  'Widening Arb Spread Stirs Baker Hughes-Halliburton Doubts',
#  'Divestitures Might Be Needed in Cytec-Solvay Tie-up',
#  'Divestitures Might Be Needed in Cytec-Solvay Tie-up',
#  "Local TV News Story Spurs Chatter on Bass Pro Purchase of Cabela's",
#  'CPUC Selects June to Decide Time Warner Cable-Charter Fate in California',
#  'Black Friday Sales Data Focus of GE-Electrolux Trial',
#  'Black Friday Sales Data Focus of GE-Electrolux Trial',
#  'Black Friday Sales Data Focus of GE-Electrolux Trial',
#  'Verizon Selling Data Centers, Not Enterprise Unit',
#  'Governments GE-Electrolux Witness Backfires',
#  'Governments GE-Electrolux Witness Backfires',
#  'Governments GE-Electrolux Witness Backfires',
#  'Malone a Focus of FCCs Time Warner Cable-Charter Review',
#  'AT&T Data Center Auction Fails',
#  'AT&T Data Center Auction Fails',
#  'Staples-Office Depot Fix Questionable',
#  'PUC Setback Another Hurdle for Hawaiian Electric-NextEra Merger',
#  'PUC Setback Another Hurdle for Hawaiian Electric-NextEra Merger',
#  'Government Claims Coordination Among GE, Whirlpool, and Electrolux',
#  'Government Claims Coordination Among GE, Whirlpool, and Electrolux',
#  'Government Claims Coordination Among GE, Whirlpool, and Electrolux',
#  'Government Claims Coordination Among GE, Whirlpool, and Electrolux',
#  'Government Claims Coordination Among GE, Whirlpool, and Electrolux',
#  'Judge in GE-Electrolux Trial Asks for Settlement as DOJ Nears Conclusion of Case',
#  'Judge in GE-Electrolux Trial Asks for Settlement as DOJ Nears Conclusion of Case',
#  'Judge in GE-Electrolux Trial Asks for Settlement as DOJ Nears Conclusion of Case',
#  'Judge in GE-Electrolux Trial Asks for Settlement as DOJ Nears Conclusion of Case',
#  'Clock Ticking on Suncors Offer for Canadian Oil Sands',
#  'Judge Questions Testimony of Electrolux CEO',
#  'Judge Questions Testimony of Electrolux CEO',
#  'Judge Questions Testimony of Electrolux CEO',
#  'Judge Questions Testimony of Electrolux CEO',
#  'Judge Questions Testimony of Electrolux CEO',
#  'Will Time Warner Cable-Charter Merger Hurt Online Video Rivals?',
#  'Live Updates:  U.S. v. Electrolux and GE',
#  'Live Updates:  U.S. v. Electrolux and GE',
#  'Live Updates:  U.S. v. Electrolux and GE',
#  'Live Updates:  U.S. v. Electrolux and GE',
#  'Live Updates:  U.S. v. Electrolux and GE',
#  'Essendant Not Clear Office Depot-Staples Fix',
#  'Essendant Not Clear Office Depot-Staples Fix',
#  'Black Friday Could Be GE-Electrolux Determinant',
#  'Black Friday Could Be GE-Electrolux Determinant',
#  'Black Friday Could Be GE-Electrolux Determinant',
#  'Black Friday Could Be GE-Electrolux Determinant',
#  'NextEra Argues Hawaiis Clean Energy Future at Risk Without Merger',
#  'NextEra Argues Hawaiis Clean Energy Future at Risk Without Merger',
#  'NextEras Robo Tries to Avoid Cross Examination at Hawaii PUC hearings',
#  'NextEras Robo Tries to Avoid Cross Examination at Hawaii PUC hearings',
#  'GE-Electrolux Go For Knockout in Antitrust Trial',
#  'GE-Electrolux Go For Knockout in Antitrust Trial',
#  'GE-Electrolux Go For Knockout in Antitrust Trial',
#  'GE-Electrolux Go For Knockout in Antitrust Trial',
#  'GE-Electrolux Go For Knockout in Antitrust Trial',
#  'Teradata May Explore Sale Next Year',
#  'Will the Office Depot-Staples Deal Face a Challenge?',
#  'Unisplendour Investment in Western Digital Should Draw Modest CFIUS Scrutiny',
#  'Live Updates: DOJ v. GE-Electrolux Week Four',
#  'Live Updates: DOJ v. GE-Electrolux Week Four',
#  'Live Updates: DOJ v. GE-Electrolux Week Four',
#  'Global Regulators Coordinate Baker Hughes-Halliburton Review',
#  'Global Regulators Coordinate Baker Hughes-Halliburton Review',
#  'GE-Electrolux Antitrust Trial Heads to Finish Line',
#  'GE-Electrolux Antitrust Trial Heads to Finish Line',
#  'GE-Electrolux Antitrust Trial Heads to Finish Line',
#  'GE-Electrolux Antitrust Trial Heads to Finish Line',
#  'Live Updates: DOJ v. GE-Electrolux Week Four, Part II',
#  'Live Updates: DOJ v. GE-Electrolux Week Four, Part II',
#  'Live Updates: DOJ v. GE-Electrolux Week Four, Part II',
#  'Clocks Runs Out On GE-Electrolux Deal',
#  'Clocks Runs Out On GE-Electrolux Deal',
#  'Clocks Runs Out On GE-Electrolux Deal',
#  'FedEx-TNT Deal Advances:  Some Questions Remain over Brazil and China',
#  'FedEx-TNT Deal Advances:  Some Questions Remain over Brazil and China',
#  'Telecoms Not Expected to Show Strong Interest in Yahoos Core Business',
#  'Rocky Start for Hawaiis Hearings on Hawaiian Electric-NextEra Merger',
#  'Rocky Start for Hawaiis Hearings on Hawaiian Electric-NextEra Merger',
#  'Zayo Interested in Equinix European Divestments',
#  'Analysts See Divestitures Easing Path to Baker Hughes-Halliburton Deal Closing',
#  'Analysts See Divestitures Easing Path to Baker Hughes-Halliburton Deal Closing',
#  'Analysts See Divestitures Easing Path to Baker Hughes-Halliburton Deal Closing',
#  'Next Steps for Office Depot-Staples',
#  'Jury Is Out on Clouderas Valuation',
#  'Jury Is Out on Clouderas Valuation',
#  'Jury Is Out on Clouderas Valuation',
#  'China Air Transport Association Might Slow FedEx-TNT Deal',
#  'Lululemon: Logical Combo with Nike or Under Armour?',
#  'Lululemon: Logical Combo with Nike or Under Armour?',
#  'Lululemon: Logical Combo with Nike or Under Armour?',
#  'SoftBank Investments into Sprint to Continue',
#  'SoftBank Investments into Sprint to Continue',
#  'SoftBank Investments into Sprint to Continue',
#  'California Complicated for Health Insurance Mergers',
#  'California Complicated for Health Insurance Mergers',
#  'California Complicated for Health Insurance Mergers',
#  'California Complicated for Health Insurance Mergers',
#  'New Potash Bid for K+S Needs Stable Prices',
#  'New Potash Bid for K+S Needs Stable Prices',
#  'China Postal Regulator May Request Remedies in FedEx-TNT Merger',
#  'Uncertainty Persists in Baker Hughes-Halliburton Deal',
#  'Uncertainty Persists in Baker Hughes-Halliburton Deal',
#  'TECO-Emera Merger Focus on New Mexico Gas',
#  'Pepco-Exelon Do-Over Clouded by Scandal',
#  'Pepco-Exelon Do-Over Clouded by Scandal',
#  'Microchip Has Advantage over Dialog in Atmel Contest',
#  'Hurdle for Altice and Charter Deal Approvals in New York',
#  '“Snack”\x9d Email Complicates Hawaiian Electric-NextEra Review',
#  '“Snack”\x9d Email Complicates Hawaiian Electric-NextEra Review',
#  "Charter's FCC Review Pause Symbolic",
#  'ON Semiconductor Has Superior Proposal Investors Say',
#  'Former FTC Attorney Questions Odds of Staples Settlement',
#  'Hawaii Regulator Exposes NextEra Settlement with DOD',
#  'Hawaii Regulator Exposes NextEra Settlement with DOD',
#  'Legal Changes and Capital Flows Favor REITs in 2016',
#  'Legal Changes and Capital Flows Favor REITs in 2016',
#  'AB InBev-SABMiller Face Scrutiny in Australia and China',
#  'AB InBev-SABMiller Face Scrutiny in Australia and China',
#  'AB InBev-SABMiller Face Scrutiny in Australia and China',
#  'AB InBev-SABMiller Face Scrutiny in Australia and China',
#  'View on Device Test to Drive Baxalta-Shire Deal',
#  'View on Device Test to Drive Baxalta-Shire Deal',
#  'Experts Doubt Office Depot-Staples Settlement with FTC',
#  'Oi Regulatory and Financial Woes Obstacles to Merger with TIM Brasil',
#  "FCC's Incentive Auction May Face Muted Demand",
#  "FCC's Incentive Auction May Face Muted Demand",
#  "FCC's Incentive Auction May Face Muted Demand",
#  "FCC's Incentive Auction May Face Muted Demand",
#  "FCC's Incentive Auction May Face Muted Demand",
#  'DOJ Seen Widening Probe of SABMiller-InBev Merger',
#  'DOJ Seen Widening Probe of SABMiller-InBev Merger',
#  'Googles Participation in Spectrum Auctions Questioned',
#  "BMO's Interest in US Assets Could Extend to CIT",
#  'CenturyLink Confronts Lower Price for Data Centers',
#  'CenturyLink Confronts Lower Price for Data Centers',
#  'No Signs CPUC Will Speed Time Warner Cable-Charter Review',
#  'Limited Competition Concerns for AB InBev-SABMiller Merger in Australia',
#  'Executive Sees Logic of CUB Sale by Merged AB InBev-SABMiller',
#  'Analysts Cautious on Shareholder Support for Vonovia Bid',
#  'Analysts Cautious on Shareholder Support for Vonovia Bid',
#  'Kohls Appears Able to Service Debt for LBO',
#  'Kohls Appears Able to Service Debt for LBO',
#  'Few Remedies Seen in California Approvals of Health Insurance Mergers',
#  'Few Remedies Seen in California Approvals of Health Insurance Mergers',
#  'Few Remedies Seen in California Approvals of Health Insurance Mergers',
#  'Few Remedies Seen in California Approvals of Health Insurance Mergers',
#  'Baxalta-Shire Spread Expected to Face Pressure',
#  'Baxalta-Shire Spread Expected to Face Pressure',
#  'New Mexico Talks Latest Focus of  Emera-TECO Merger',
#  "Navy's Secret Deal with NextEra Emerges in Hawaii Case",
#  "Navy's Secret Deal with NextEra Emerges in Hawaii Case",
#  'Verizon Denies It Bid for Yahoos Core Business',
#  "Time Warner Cable-Charter Concerns Voiced at Tuesday's California Hearing",
#  'Judge Hampers Staples Efforts In Antitrust Hearing',
#  'Success of Verizons Media Business Questioned',
#  'Demag in Play with Zoomlion Move to Acquire Terex',
#  'Cox Implicates Media General Deal in Dispute with Nexstar',
#  'Cox Implicates Media General Deal in Dispute with Nexstar',
#  "Brazil's CADE Clears Fedex-TNT Deal",
#  "Brazil's CADE Clears Fedex-TNT Deal",
#  'AB InBev Fends Off Craft Brewers in SABMiller Merger Review',
#  'Charter Petitions CPUC to Improve Time Warner Cable Timeline',
#  'Charter Petitions CPUC to Improve Time Warner Cable Timeline',
#  'Cabelas Credit Card Business Called “Best in Class”\x9d',
#  'Cabelas Credit Card Business Called “Best in Class”\x9d',
#  'FTC Not Hindered by Third Parties in Staples Litigation',
#  'Syngenta-ChemChina Review Could Focus on IP Transfer',
#  'Financing for Chinese Outbound M&A Carries Risk',
#  'Financing for Chinese Outbound M&A Carries Risk',
#  'MetLife Heads to Court Over SIFI Designation',
#  'Live Updates:  MetLife v. FSOC in U.S. District Court',
#  'Judge Questions Too-Big-to-Fail Tab for MetLife',
#  'Judge Questions Too-Big-to-Fail Tab for MetLife',
#  'EC Referral Likely in Wincor-Diebold Merger',
#  'California ALJ Advances Time Warner Cable-Charter Decision Date',
#  'Revised:  NextEra Proceedings in Hawaii Remain Contentious',
#  'Revised:  NextEra Proceedings in Hawaii Remain Contentious',
#  'Exelon-Pepco Merger Appears Headed for Approval',
#  'Exelon-Pepco Merger Appears Headed for Approval',
#  'Williams-Energy Transfer Deal Advances Amid Controversy',
#  'Williams-Energy Transfer Deal Advances Amid Controversy',
#  'UPS Could Appeal FedEx-TNT Approval in Brazil',
#  'UPS Could Appeal FedEx-TNT Approval in Brazil',
#  'Fannie/Freddie Appeal Clouded by Secrecy',
#  'Fannie/Freddie Appeal Clouded by Secrecy',
#  'Halliburton May Need Further Divestitures for ACCC Clearance',
#  'Halliburton May Need Further Divestitures for ACCC Clearance',
#  'CPUC Commissioners Might Split on Time Warner Cable-Charter',
#  'Williams-Energy Transfer Merger Question Raised by Bond Covenant',
#  'Williams-Energy Transfer Merger Question Raised by Bond Covenant',
#  'Challenge to TNT/FedEx Approval in Brazil Likely Accepted by Tribunal',
#  'Challenge to TNT/FedEx Approval in Brazil Likely Accepted by Tribunal',
#  'Staples Puts Essendant "Fix" in Judge\'s Hands',
#  'Staples Puts Essendant "Fix" in Judge\'s Hands',
#  'Treasury Seen Doubtful on New Inversion Rules',
#  'Treasury Seen Doubtful on New Inversion Rules',
#  'Ingram Micro Says Tianjin Tianhai Merger Should Not See CFIUS Review',
#  'Zoomlions Financing for Terex Bid Questioned',
#  'Termination Raised as Issue in Hawaiian Electric/NextEra Proceedings',
#  'Termination Raised as Issue in Hawaiian Electric/NextEra Proceedings',
#  'Halliburton Appears to Make Progress at EC Despite Stopped Clock',
#  'Halliburton Appears to Make Progress at EC Despite Stopped Clock',
#  'Cross-Ownership Suggests Positive SanDisk/Western Digital Vote',
#  'EC Appears Receptive to Latest Halliburton Proposal',
#  'EC Appears Receptive to Latest Halliburton Proposal',
#  'SABMiller/AB InBev Merger Could See Behavioral Remedies in South Africa',
#  'Old Divisions Threaten Pepco/Exelon Deal',
#  'Old Divisions Threaten Pepco/Exelon Deal',
#  'Pepco Talks Focus on Balancing Residential, Commercial Ratepayer Benefits',
#  'Pepco Talks Focus on Balancing Residential, Commercial Ratepayer Benefits',
#  'Staples to Press “Amazon Defense”\x9d Against FTC Claims',
#  'ORA Proposes Conditions for Time Warner Cable/Charter Merger in California',
#  'Live Update:  FTC v. Staples Status Conference March 4',
#  'Amazon Asks Judge to Protect Secrets in Staples Trial',
#  'South Africa Unions Want Guarantees in SABMiller/AB InBev Merger',
#  'ACCC Review of SABMiller/AB InBev Deal Likely Hinges on Licensing Agreements',
#  'Exelon Reshuffles Deck with Latest Pepco Offer',
#  'Brazilian Tribunal Reviews Baker Hughes/Halliburton Divestiture Plan',
#  'CEO Testimony Could Prove Risky for Staples',
#  'SoftBank Expected to Participate in Upcoming Spectrum Auction',
#  'SoftBank Expected to Participate in Upcoming Spectrum Auction',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'FCC Expected to Announce Bidders for Spectrum Shortly',
#  'Pepco/Exelon Waiting for DC Mayor',
#  'ACCC Review of Baker Hughes/Halliburton Proceeds while Industry Backdrop Darkens']

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
train_x = headline[:int(len(headline)/5*4)]
test_x = headline[int(len(headline)/5*4):]
train_y = label[:int(len(headline)/5*4)]
test_y = label[int(len(headline)/5*4):]

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 1493

# %% [markdown]
# ### Train our Model

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = np.asarray(train_y)
Y = Y.reshape(len(Y),1)

# %%
# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# The cost after training is 0.69311028.
# The resulting vector of weights is [6e-08, 7.4e-06, 8.1e-07]

# %% [markdown]
# ## Prediction Function

# %%
# UNQ_C4 GRADED FUNCTION: predict_headline
def predict_headline(headline, freqs, theta):
    '''
    Input: 
        headline: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a headline being positive or negative
    '''
    
    # extract the features of the headline and store it into x
    x = extract_features(headline, freqs, process_headline=process_headline)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x,theta))
    
    return y_pred

# %%
# UNQ_C5 GRADED FUNCTION: test_logistic_regression
def test_logistic_regression(test_x, test_y, freqs, theta, predict_headline=predict_headline):
    """
    Input: 
        test_x: a list of headlines
        test_y: (m, 1) vector with the corresponding labels for the list of headlines
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of headlines classified correctly) / (total # of headlines)
    """
    
    # the list for storing predictions
    y_hat = []
    
    for headline in test_x:
        # get the label prediction for the headline
        y_pred = predict_headline(headline,freqs,theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = (np.asarray(y_hat) == np.squeeze(test_y)).sum()/test_y.shape[0]

    
    return accuracy

# %%
# test labels corresponding to X
test_y = np.asarray(test_y)
test_y = test_y.reshape(len(test_y),1)

tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmpaccuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.6264
